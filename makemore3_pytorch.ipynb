# %%
import torch
import matplotlib.pyplot as plt
import torch.nn.functional as F

# %% [markdown]
# ## Uniform and Gaussian(Normal) distribution in Pytorch

# %%
unifrom_distribution = torch.rand(10000)
plt.hist(unifrom_distribution,bins=60);

# %%
normal_distribution = torch.randn(10000)
plt.hist(normal_distribution,bins=60);
